# %%
import pandas as pd

reviews = pd.read_csv('artwork_data.csv', low_memory=False)
pd.set_option('display.max_columns', 5)

# %%
reviews
# Out:
#            id accession_number  ...  \
# 0        1035           A00001  ...
# 1        1036           A00002  ...
# 2        1037           A00003  ...
# 3        1038           A00004  ...
# 4        1039           A00005  ...
# ...       ...              ...  ...
# 69196  122960           T13865  ...
# 69197  122961           T13866  ...
# 69198  121181           T13867  ...
# 69199  112306           T13868  ...
# 69200  127035           T13869  ...
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# ...

# %%
reviews.artist
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
reviews.columns
# Out:
# Index(['accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
reviews['artist'][0]
# Out:
# 'Blake, Robert'

# %%
reviews['artist'][1035]
# Out:
# 'Beerbohm, Sir Max'

# %%
reviews['title'][0]
# Out:
# 'A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch'

# %%
reviews.loc[:10,['artist','title']]
# Out:
#             artist                                              title
# 0    Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1    Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2    Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3    Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4   Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5   Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6   Blake, William                        The Baffled Devils Fighting
# 7   Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8   Blake, William                 The Serpent Attacking Buoso Donati
# 9   Blake, William                 The Pit of Disease: The Falsifiers
# 10  Blake, William           Dante Striking against Bocca Degli Abati

# %%
print(reviews.loc[:10,['artist','title']].to_markdown())
# Out:
# |    | artist         | title                                                                                                          |
# |---:|:---------------|:---------------------------------------------------------------------------------------------------------------|
# |  0 | Blake, Robert  | A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch |
# |  1 | Blake, Robert  | Two Drawings of Frightened Figures, Probably for ‘The Approach of Doom’                                        |
# |  2 | Blake, Robert  | The Preaching of Warning. Verso: An Old Man Enthroned Between Two Groups of Figures, by ?William Blake         |
# |  3 | Blake, Robert  | Six Drawings of Figures with Outstretched Arms                                                                 |
# |  4 | Blake, William | The Circle of the Lustful: Francesca da Rimini (‘The Whirlwind of Lovers’)                                     |
# ...

# %%
print(reviews.loc[:5,'dimensions'].to_markdown())
# Out:
# |    | dimensions            |
# |---:|:----------------------|
# |  0 | support: 394 x 419 mm |
# |  1 | support: 311 x 213 mm |
# |  2 | support: 343 x 467 mm |
# |  3 | support: 318 x 394 mm |
# |  4 | image: 243 x 335 mm   |
# |  5 | image: 240 x 338 mm   |

# %%
reviews['dimensions'][0]
# Out:
# 'support: 394 x 419 mm'

# %%
reviews.iloc[0:5,6:8]
# Out:
#                  dateText                                             medium
# 0          date not known  Watercolour, ink, chalk and graphite on paper....
# 1          date not known                                  Graphite on paper
# 2                 ?c.1785        Graphite on paper. Verso: graphite on paper
# 3          date not known                                  Graphite on paper
# 4  1826–7, reprinted 1892                            Line engraving on paper

# %%
reviews.iloc[:,1:8:2]
# Out:
#       accession_number artistRole  \
# 0               A00001     artist
# 1               A00002     artist
# 2               A00003     artist
# 3               A00004     artist
# 4               A00005     artist
# ...                ...        ...
# 69196           T13865     artist
# 69197           T13866     artist
# 69198           T13867     artist
# 69199           T13868     artist
# 69200           T13869     artist
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# 2      The Preaching of Warning. Verso: An Old Man En...
# 3         Six Drawings of Figures with Outstretched Arms
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...                                                  ...
# 69196                        Larvae (from Tampax Romana)
# 69197                   Living Womb (from Tampax Romana)
# ...

# %%
reviews.iloc[:3,1]
# Out:
# 0    A00001
# 1    A00002
# 2    A00003
# Name: accession_number, dtype: object

# %%
reviews.iloc[[0,2,8,12],1]
# Out:
# 0     A00001
# 2     A00003
# 8     A00009
# 12    A00013
# Name: accession_number, dtype: object

# %%
reviews.iloc[-5:,1]
# Out:
# 69196    T13865
# 69197    T13866
# 69198    T13867
# 69199    T13868
# 69200    T13869
# Name: accession_number, dtype: object

# %%
reviews.loc[0:5, 'dimensions']
# Out:
# 0    support: 394 x 419 mm
# 1    support: 311 x 213 mm
# 2    support: 343 x 467 mm
# 3    support: 318 x 394 mm
# 4      image: 243 x 335 mm
# 5      image: 240 x 338 mm
# Name: dimensions, dtype: object

# %%
reviews.loc[[0,4], ['artist', 'title', 'dimensions']]
# Out:
#            artist                                              title  \
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#               dimensions
# 0  support: 394 x 419 mm
# 4    image: 243 x 335 mm

# %%
reviews.loc[[0,3,150],'artist': 'year']
# Out:
#               artist artistRole  ...                           creditLine  \
# 0      Blake, Robert     artist  ...  Presented by Mrs John Richmond 1922
# 3      Blake, Robert     artist  ...  Presented by Mrs John Richmond 1922
# 150  Callow, William     artist  ...                       Purchased 1912
#
#      year
# 0     NaN
# 3     NaN
# 150  1844
#
# [3 rows x 8 columns]

# %%
reviews.iloc[0,0:]
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistRole                                                       artist
# artistId                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText                                                 date not known
# medium                Watercolour, ink, chalk and graphite on paper....
# creditLine                          Presented by Mrs John Richmond 1922
# year                                                                NaN
# acquisitionYear                                                  1922.0
# dimensions                                        support: 394 x 419 mm
# width                                                               394
# ...
