# %%
import pandas as pd
import numpy as np

reviews = pd.read_csv('artwork_data.csv', low_memory=False)
pd.set_option('display.max_columns', 5)

# %%
reviews
# Out:
#            id accession_number  ...  \
# 0        1035           A00001  ...
# 1        1036           A00002  ...
# 2        1037           A00003  ...
# 3        1038           A00004  ...
# 4        1039           A00005  ...
# ...       ...              ...  ...
# 69196  122960           T13865  ...
# 69197  122961           T13866  ...
# 69198  121181           T13867  ...
# 69199  112306           T13868  ...
# 69200  127035           T13869  ...
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# ...

# %%
reviews.artistId.idxmax()
# Out:
# 42695

# %%
reviews.artist.value_counts()
# Out:
# artist
# Turner, Joseph Mallord William                                                           39389
# Jones, George                                                                             1046
# Moore, Henry, OM, CH                                                                       623
# Daniell, William                                                                           612
# Beuys, Joseph                                                                              578
#                                                                                          ...
# Andrade, Jonathas de                                                                         1
# Rhodes, Lis                                                                                  1
# T R Uthco (Doug Hall born 1944, Diane Andrews Hall born 1945, Jody Procter 1944-1998)        1
# Atlas, Charles                                                                               1
# ...

# %%
reviews['artist'].nunique()
# Out:
# 3336

# %%
reviews.artist.unique()
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       shape=(3336,), dtype=object)

# %%
reviews.artistId.mean()
# Out:
# np.float64(1201.0632505310616)

# %%
reviews.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
reviews.artist
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
reviews.columns
# Out:
# Index(['accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
reviews['artist'][0]
# Out:
# 'Blake, Robert'

# %%
reviews['artist'][1035]
# Out:
# 'Beerbohm, Sir Max'

# %%
reviews['title'][0]
# Out:
# 'A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch'

# %%
reviews.loc[0:3,['artist', 'title']]
# Out:
#           artist                                              title
# 0  Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1  Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2  Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3  Blake, Robert     Six Drawings of Figures with Outstretched Arms

# %%
reviews.iloc[0:3, 5:6]
# Out:
#                                                title
# 0  A Figure Bowing before a Seated Old Man with h...
# 1  Two Drawings of Frightened Figures, Probably f...
# 2  The Preaching of Warning. Verso: An Old Man En...

# %%
reviews.iloc[-3:-1,[2,3,4]]
# Out:
#               artist artistRole  artistId
# 69198   Hatoum, Mona     artist      2365
# 69199  Creed, Martin     artist      2760

# %%
reviews.loc[:3,'artist':'title']
# Out:
#           artist artistRole  artistId  \
# 0  Blake, Robert     artist        38
# 1  Blake, Robert     artist        38
# 2  Blake, Robert     artist        38
# 3  Blake, Robert     artist        38
#
#                                                title
# 0  A Figure Bowing before a Seated Old Man with h...
# 1  Two Drawings of Frightened Figures, Probably f...
# 2  The Preaching of Warning. Verso: An Old Man En...
# 3     Six Drawings of Figures with Outstretched Arms

# %%
print(reviews.loc[:10,['artist','title']].to_markdown())
# Out:
# |    | artist         | title                                                                                                          |
# |---:|:---------------|:---------------------------------------------------------------------------------------------------------------|
# |  0 | Blake, Robert  | A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch |
# |  1 | Blake, Robert  | Two Drawings of Frightened Figures, Probably for ‘The Approach of Doom’                                        |
# |  2 | Blake, Robert  | The Preaching of Warning. Verso: An Old Man Enthroned Between Two Groups of Figures, by ?William Blake         |
# |  3 | Blake, Robert  | Six Drawings of Figures with Outstretched Arms                                                                 |
# |  4 | Blake, William | The Circle of the Lustful: Francesca da Rimini (‘The Whirlwind of Lovers’)                                     |
# ...

# %%
print(reviews.loc[:5,'dimensions'].to_markdown())
# Out:
# |    | dimensions            |
# |---:|:----------------------|
# |  0 | support: 394 x 419 mm |
# |  1 | support: 311 x 213 mm |
# |  2 | support: 343 x 467 mm |
# |  3 | support: 318 x 394 mm |
# |  4 | image: 243 x 335 mm   |
# |  5 | image: 240 x 338 mm   |

# %%
reviews['dimensions'][0]
# Out:
# 'support: 394 x 419 mm'

# %%
reviews.iloc[0:5,6:8]
# Out:
#                  dateText                                             medium
# 0          date not known  Watercolour, ink, chalk and graphite on paper....
# 1          date not known                                  Graphite on paper
# 2                 ?c.1785        Graphite on paper. Verso: graphite on paper
# 3          date not known                                  Graphite on paper
# 4  1826–7, reprinted 1892                            Line engraving on paper

# %%
reviews.iloc[:,1:8:2]
# Out:
#       accession_number artistRole  \
# 0               A00001     artist
# 1               A00002     artist
# 2               A00003     artist
# 3               A00004     artist
# 4               A00005     artist
# ...                ...        ...
# 69196           T13865     artist
# 69197           T13866     artist
# 69198           T13867     artist
# 69199           T13868     artist
# 69200           T13869     artist
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# 2      The Preaching of Warning. Verso: An Old Man En...
# 3         Six Drawings of Figures with Outstretched Arms
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...                                                  ...
# 69196                        Larvae (from Tampax Romana)
# 69197                   Living Womb (from Tampax Romana)
# ...

# %%
reviews.iloc[:3,1]
# Out:
# 0    A00001
# 1    A00002
# 2    A00003
# Name: accession_number, dtype: object

# %%
reviews.iloc[[0,2,8,12],1]
# Out:
# 0     A00001
# 2     A00003
# 8     A00009
# 12    A00013
# Name: accession_number, dtype: object

# %%
reviews.iloc[-5:,1]
# Out:
# 69196    T13865
# 69197    T13866
# 69198    T13867
# 69199    T13868
# 69200    T13869
# Name: accession_number, dtype: object

# %%
reviews.loc[0:5, 'dimensions']
# Out:
# 0    support: 394 x 419 mm
# 1    support: 311 x 213 mm
# 2    support: 343 x 467 mm
# 3    support: 318 x 394 mm
# 4      image: 243 x 335 mm
# 5      image: 240 x 338 mm
# Name: dimensions, dtype: object

# %%
reviews.loc[[0,4], ['artist', 'title', 'dimensions']]
# Out:
#            artist                                              title  \
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#               dimensions
# 0  support: 394 x 419 mm
# 4    image: 243 x 335 mm

# %%
reviews.loc[[0,3,150],'artist': 'year']
# Out:
#               artist artistRole  ...                           creditLine  \
# 0      Blake, Robert     artist  ...  Presented by Mrs John Richmond 1922
# 3      Blake, Robert     artist  ...  Presented by Mrs John Richmond 1922
# 150  Callow, William     artist  ...                       Purchased 1912
#
#      year
# 0     NaN
# 3     NaN
# 150  1844
#
# [3 rows x 8 columns]

# %%
reviews.iloc[-5:,0:]
# Out:
#            id accession_number  ...  \
# 69196  122960           T13865  ...
# 69197  122961           T13866  ...
# 69198  121181           T13867  ...
# 69199  112306           T13868  ...
# 69200  127035           T13869  ...
#
#                                             thumbnailUrl  \
# 69196                                                NaN
# 69197                                                NaN
# 69198                                                NaN
# 69199                                                NaN
# 69200  http://www.tate.org.uk/art/images/work/T/T13/T...
#
#                                                      url
# 69196  http://www.tate.org.uk/art/artworks/p-orridge-...
# 69197  http://www.tate.org.uk/art/artworks/p-orridge-...
# 69198  http://www.tate.org.uk/art/artworks/hatoum-pre...
# 69199  http://www.tate.org.uk/art/artworks/creed-work...
# 69200  http://www.tate.org.uk/art/artworks/brunias-da...
#
# [5 rows x 20 columns]

# %%
n_rev = reviews.set_index("artistId")
n_rev
# Out:
#               id accession_number  ...  \
# artistId                           ...
# 38          1035           A00001  ...
# 38          1036           A00002  ...
# 38          1037           A00003  ...
# 38          1038           A00004  ...
# 39          1039           A00005  ...
# ...          ...              ...  ...
# 16646     122960           T13865  ...
# 16646     122961           T13866  ...
# 2365      121181           T13867  ...
# 2760      112306           T13868  ...
# 3824      127035           T13869  ...
#
#                                                thumbnailUrl  \
# artistId
# 38        http://www.tate.org.uk/art/images/work/A/A00/A...
# 38        http://www.tate.org.uk/art/images/work/A/A00/A...
# 38        http://www.tate.org.uk/art/images/work/A/A00/A...
# 38        http://www.tate.org.uk/art/images/work/A/A00/A...
# 39        http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                     ...
# ...

# %%
reviews.loc[:10,'artistId':'units']
# Out:
#     artistId                                              title  ... depth  \
# 0         38  A Figure Bowing before a Seated Old Man with h...  ...   NaN
# 1         38  Two Drawings of Frightened Figures, Probably f...  ...   NaN
# 2         38  The Preaching of Warning. Verso: An Old Man En...  ...   NaN
# 3         38     Six Drawings of Figures with Outstretched Arms  ...   NaN
# 4         39  The Circle of the Lustful: Francesca da Rimini...  ...   NaN
# 5         39      Ciampolo the Barrator Tormented by the Devils  ...   NaN
# 6         39                        The Baffled Devils Fighting  ...   NaN
# 7         39  The Six-Footed Serpent Attacking Agnolo Brunel...  ...   NaN
# 8         39                 The Serpent Attacking Buoso Donati  ...   NaN
# 9         39                 The Pit of Disease: The Falsifiers  ...   NaN
# 10        39           Dante Striking against Bocca Degli Abati  ...   NaN
#
#    units
# 0     mm
# 1     mm
# 2     mm
# 3     mm
# 4     mm
# ...

# %%
reviews.artist == 'Blake, Robert'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: artist, Length: 69201, dtype: bool

# %%
reviews.loc[reviews.artist == 'Blake, Robert']
# Out:
#      id accession_number  ...  \
# 0  1035           A00001  ...
# 1  1036           A00002  ...
# 2  1037           A00003  ...
# 3  1038           A00004  ...
#
#                                         thumbnailUrl  \
# 0  http://www.tate.org.uk/art/images/work/A/A00/A...
# 1  http://www.tate.org.uk/art/images/work/A/A00/A...
# 2  http://www.tate.org.uk/art/images/work/A/A00/A...
# 3  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...
# 1  http://www.tate.org.uk/art/artworks/blake-two-...
# 2  http://www.tate.org.uk/art/artworks/blake-the-...
# 3  http://www.tate.org.uk/art/artworks/blake-six-...
#
# [4 rows x 20 columns]

# %%
reviews
# Out:
#            id accession_number  ...  \
# 0        1035           A00001  ...
# 1        1036           A00002  ...
# 2        1037           A00003  ...
# 3        1038           A00004  ...
# 4        1039           A00005  ...
# ...       ...              ...  ...
# 69196  122960           T13865  ...
# 69197  122961           T13866  ...
# 69198  121181           T13867  ...
# 69199  112306           T13868  ...
# 69200  127035           T13869  ...
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# ...

# %%
reviews.loc[reviews.width == '310']
# Out:
#            id accession_number  ...  \
# 1994    97422          AR00257  ...
# 2562   105740          AR00825  ...
# 3572    28091           D00676  ...
# 7494    32032           D04639  ...
# 27925   52544           D25207  ...
# 27926   52545           D25208  ...
# 27928   52547           D25210  ...
# 27998   52617           D25280  ...
# 28012   52631           D25294  ...
# 38758   63418           D36333  ...
# 45485    9746           P02135  ...
# 45578    9835           P02228  ...
# 48619   10961           P06403  ...
# 49738   11753           P07706  ...
# 49770     747           P07738  ...
# 51531   80132           P12190  ...
# 51713   80752           P12372  ...
# 52101   27122           P13297  ...
# 52102   27123           P13298  ...
# 52520  109710           P20382  ...
# 53287   21499           P77788  ...
# 60918   17269           T05491  ...
# 62302   21090           T06887  ...
# 62329   21119           T06915  ...
# 62358   21232           T06944  ...
# ...

# %%
reviews.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
reviews.loc[((reviews.id >= 52000) & (reviews.artistId > 2000)) & (reviews.artist == 'Warhol, Andy')]
# Out:
#           id accession_number  ...  \
# 1776   97346          AR00039  ...
# 1777   97347          AR00040  ...
# 1967   97345          AR00230  ...
# 1968   97355          AR00231  ...
# 1969   97392          AR00232  ...
# ...      ...              ...  ...
# 2346   97348          AR00609  ...
# 2347   97349          AR00610  ...
# 2348   99113          AR00611  ...
# 2349   97435          AR00612  ...
# 67939  66602           T12600  ...
#
#                                             thumbnailUrl  \
# 1776                                                 NaN
# 1777                                                 NaN
# 1967                                                 NaN
# 1968                                                 NaN
# 1969                                                 NaN
# ...                                                  ...
# 2346                                                 NaN
# 2347                                                 NaN
# ...

# %%
reviews.loc[reviews.medium.isin(['Graphite on paper', 'Line engraving on paper'])]
# Out:
#            id accession_number  ...  \
# 1        1036           A00002  ...
# 3        1038           A00004  ...
# 4        1039           A00005  ...
# 5        1040           A00006  ...
# 6        1041           A00007  ...
# ...       ...              ...  ...
# 68927  117540           T13596  ...
# 68928  117542           T13597  ...
# 69091   89802           T13760  ...
# 69092   90066           T13761  ...
# 69129  117242           T13798  ...
#
#                                             thumbnailUrl  \
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# 5      http://www.tate.org.uk/art/images/work/A/A00/A...
# 6      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 68927                                                NaN
# 68928                                                NaN
# ...

# %%
reviews.loc[reviews.year.isnull()]
# Out:
#            id accession_number  ...  \
# 0        1035           A00001  ...
# 1        1036           A00002  ...
# 3        1038           A00004  ...
# 50       1505           A00051  ...
# 51       1506           A00052  ...
# ...       ...              ...  ...
# 67774   93819           T12432  ...
# 67934   27098           T12595  ...
# 67935   27108           T12596  ...
# 67989   99356           T12650  ...
# 68674  113918           T13343  ...
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 50                                                   NaN
# 51                                                   NaN
# ...                                                  ...
# 67774  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67934                                                NaN
# ...

# %%
reviews.loc[reviews.year.notnull()]
# Out:
#            id accession_number  ...  \
# 2        1037           A00003  ...
# 4        1039           A00005  ...
# 5        1040           A00006  ...
# 6        1041           A00007  ...
# 7        1042           A00008  ...
# ...       ...              ...  ...
# 69196  122960           T13865  ...
# 69197  122961           T13866  ...
# 69198  121181           T13867  ...
# 69199  112306           T13868  ...
# 69200  127035           T13869  ...
#
#                                             thumbnailUrl  \
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# 5      http://www.tate.org.uk/art/images/work/A/A00/A...
# 6      http://www.tate.org.uk/art/images/work/A/A00/A...
# 7      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# ...

# %%
reviews['id'] = range(len(reviews), 0, -1)
reviews['id']
# Out:
# 0        69201
# 1        69200
# 2        69199
# 3        69198
# 4        69197
#          ...
# 69196        5
# 69197        4
# 69198        3
# 69199        2
# 69200        1
# Name: id, Length: 69201, dtype: int64

# %%
reviews.artistId.describe()
# Out:
# count    69201.000000
# mean      1201.063251
# std       2019.422535
# min          0.000000
# 25%        558.000000
# 50%        558.000000
# 75%       1137.000000
# max      19232.000000
# Name: artistId, dtype: float64

# %%
reviews.artist.describe()
# Out:
# count                              69201
# unique                              3336
# top       Turner, Joseph Mallord William
# freq                               39389
# Name: artist, dtype: object

# %%
reviews.describe()
# Out:
#                   id      artistId  acquisitionYear         depth
# count   69201.000000  69201.000000     69156.000000   2514.000000
# mean    39148.026213   1201.063251      1910.646856    479.197772
# std     25980.468687   2019.422535        64.202148   1051.141734
# min         3.000000      0.000000      1823.000000      1.000000
# 25%     19096.000000    558.000000      1856.000000     48.250000
# 50%     37339.000000    558.000000      1856.000000    190.000000
# 75%     54712.000000   1137.000000      1982.000000    450.000000
# max    129068.000000  19232.000000      2013.000000  18290.000000
