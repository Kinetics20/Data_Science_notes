# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
seven_days = pd.date_range('2025-03-15', periods=7, freq='D')

# %%
seven_days.day
# Out:
# Index([15, 16, 17, 18, 19, 20, 21], dtype='int32')

# %%
seven_days[0]
# Out:
# Timestamp('2025-03-15 00:00:00')

# %%
for day in seven_days:
    print(type(day))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
for day in seven_days:
    print(day.dayofweek, day.weekday(), day.day_name())
# Out:
# 5 5 Saturday
# 6 6 Sunday
# 0 0 Monday
# 1 1 Tuesday
# 2 2 Wednesday
# 3 3 Thursday
# 4 4 Friday

# %%
data = pd.read_csv('nyc.csv')

# %%
data.dtypes
# Out:
# date      object
# ozone    float64
# pm25     float64
# co       float64
# dtype: object

# %%
data.set_index('date', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6317 entries, 1999-07-01 to 2017-03-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ozone   6317 non-null   float64
#  1   pm25    6317 non-null   float64
#  2   co      6317 non-null   float64
# dtypes: float64(3)
# memory usage: 197.4+ KB

# %%
data.plot(subplots=True, linewidth = .1)

plt.show()

# %%
data2 = pd.read_csv('nyc.csv', index_col=['date'], parse_dates=True)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6317 entries, 1999-07-01 to 2017-03-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ozone   6317 non-null   float64
#  1   pm25    6317 non-null   float64
#  2   co      6317 non-null   float64
# dtypes: float64(3)
# memory usage: 197.4 KB

# %%
yahoo = pd.read_csv('yahoo.csv', index_col=['date'], parse_dates=True)
yahoo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 782 entries, 2013-01-02 to 2015-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   756 non-null    float64
# dtypes: float64(1)
# memory usage: 12.2 KB

# %%
yahoo.loc['2013']
# Out:
#             price
# date
# 2013-01-02  20.08
# 2013-01-03  19.78
# 2013-01-04  19.86
# 2013-01-07  19.40
# 2013-01-08  19.66
# ...           ...
# 2013-12-25    NaN
# 2013-12-26  40.65
# 2013-12-27  40.49
# 2013-12-30  40.20
# 2013-12-31  40.44
#
# [260 rows x 1 columns]

# %%
yahoo.loc['2013':'2017']
# Out:
#             price
# date
# 2013-01-02  20.08
# 2013-01-03  19.78
# 2013-01-04  19.86
# 2013-01-07  19.40
# 2013-01-08  19.66
# ...           ...
# 2015-12-25    NaN
# 2015-12-28  33.60
# 2015-12-29  34.04
# 2015-12-30  33.37
# 2015-12-31  33.26
#
# [782 rows x 1 columns]

# %%
yahoo.loc['2013','2015']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2015'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 yahoo.loc['2013','2015']
#
# ...

# %%
yahoo_sample = yahoo.loc['2013':'2015']

# %%
ax = yahoo_sample.plot()


ax.set_title('Yahoo')

plt.show()

# %%
co = pd.read_csv('co_cities.csv', index_col=['date'], parse_dates=True)

# %%
co.head()
# Out:
#              Chicago  Los Angeles  New York
# date
# 2005-01-01  0.317763     0.777657  0.639830
# 2005-01-03  0.520833     0.349547  0.969572
# 2005-01-04  0.477083     0.626630  0.905208
# 2005-01-05  0.348822     0.613814  0.769176
# 2005-01-06  0.572917     0.792596  0.815761

# %%
co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1898 entries, 2005-01-01 to 2010-12-31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Chicago      1898 non-null   float64
#  1   Los Angeles  1898 non-null   float64
#  2   New York     1898 non-null   float64
# dtypes: float64(3)
# memory usage: 59.3 KB

# %%
co.asfreq('D')
# Out:
#              Chicago  Los Angeles  New York
# date
# 2005-01-01  0.317763     0.777657  0.639830
# 2005-01-02       NaN          NaN       NaN
# 2005-01-03  0.520833     0.349547  0.969572
# 2005-01-04  0.477083     0.626630  0.905208
# 2005-01-05  0.348822     0.613814  0.769176
# ...              ...          ...       ...
# 2010-12-27  0.510417     0.669384  0.414583
# 2010-12-28  0.479166     0.669129  0.425278
# 2010-12-29  0.460417     0.291757  0.400924
# 2010-12-30  0.364772     0.101042  0.744792
# 2010-12-31  0.381250     0.410824  0.784653
#
# [2191 rows x 3 columns]

# %%
co.asfreq('D').plot(subplots=True)
plt.show()

# %%
co.asfreq('ME').plot(subplots=True)
plt.show()

# %%
co.asfreq('MS').head()
# Out:
#              Chicago  Los Angeles  New York
# date
# 2005-01-01  0.317763     0.777657  0.639830
# 2005-02-01  0.481250     1.038180  1.351563
# 2005-03-01  0.433333     0.365942  0.690104
# 2005-04-01  0.635598     0.513360  0.848201
# 2005-05-01  0.345833     0.222418  0.710416

# %%
co.asfreq('D').head()
# Out:
#              Chicago  Los Angeles  New York
# date
# 2005-01-01  0.317763     0.777657  0.639830
# 2005-01-02       NaN          NaN       NaN
# 2005-01-03  0.520833     0.349547  0.969572
# 2005-01-04  0.477083     0.626630  0.905208
# 2005-01-05  0.348822     0.613814  0.769176

# %%
google = pd.read_csv('google.csv', index_col=['Date'], parse_dates=True)

# %%
google.head()
# Out:
#              Close
# Date
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-04     NaN
# 2014-01-05     NaN
# 2014-01-06  558.10

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1094 entries, 2014-01-02 to 2016-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   756 non-null    float64
# dtypes: float64(1)
# memory usage: 17.1 KB

# %%
google = google.asfreq('B')

# %%
google
# Out:
#              Close
# Date
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-06  558.10
# 2014-01-07  568.86
# 2014-01-08  570.04
# ...            ...
# 2016-12-26     NaN
# 2016-12-27  791.55
# 2016-12-28  785.05
# 2016-12-29  782.79
# 2016-12-30  771.82
#
# [782 rows x 1 columns]

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 782 entries, 2014-01-02 to 2016-12-30
# Freq: B
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   756 non-null    float64
# dtypes: float64(1)
# memory usage: 12.2 KB

# %%
google['lagged'] = google['Close'].shift(periods=-90)
google['shifted'] = google['Close'].shift(periods=90)

# %%
google
# Out:
#              Close  lagged  shifted
# Date
# 2014-01-02  556.00  511.00      NaN
# 2014-01-03  551.95  518.73      NaN
# 2014-01-06  558.10  529.92      NaN
# 2014-01-07  568.86  533.09      NaN
# 2014-01-08  570.04  526.65      NaN
# ...            ...     ...      ...
# 2016-12-26     NaN     NaN   772.15
# 2016-12-27  791.55     NaN   772.08
# 2016-12-28  785.05     NaN   769.64
# 2016-12-29  782.79     NaN   769.41
# 2016-12-30  771.82     NaN   769.54
#
# [782 rows x 3 columns]

# %%
google.plot()
plt.show()

# %%
(google['Close'] - google['shifted']).tail(10)
# Out:
# Date
# 2016-12-19    11.76
# 2016-12-20    19.28
# 2016-12-21    14.65
# 2016-12-22    13.76
# 2016-12-23    14.49
# 2016-12-26      NaN
# 2016-12-27    19.47
# 2016-12-28    15.41
# 2016-12-29    13.38
# 2016-12-30     2.28
# Freq: B, dtype: float64

# %%
google['Close'].diff(3)
# Out:
# Date
# 2014-01-02      NaN
# 2014-01-03      NaN
# 2014-01-06      NaN
# 2014-01-07    12.86
# 2014-01-08    18.09
#               ...
# 2016-12-26      NaN
# 2016-12-27     0.29
# 2016-12-28    -4.86
# 2016-12-29      NaN
# 2016-12-30   -19.73
# Freq: B, Name: Close, Length: 782, dtype: float64

# %%
google['Close'].sub(google['shifted']).tail()
# Out:
# Date
# 2016-12-26      NaN
# 2016-12-27    19.47
# 2016-12-28    15.41
# 2016-12-29    13.38
# 2016-12-30     2.28
# Freq: B, dtype: float64

# %%
google['Close'].sub(google['shifted']).value_counts()
# Out:
# 3.87      2
# 87.54     2
# 4.52      2
# 5.39      2
# 103.57    2
#          ..
# 35.16     1
# 21.79     1
# 20.34     1
# 10.84     1
# 7.02      1
# Name: count, Length: 641, dtype: int64

# %%
from collections import Counter

# %%
Counter(google['Close'].sub(google['shifted']))
# Out:
# Counter({3.8700000000000045: 2,
#          4.519999999999982: 2,
#          5.389999999999986: 2,
#          125.6099999999999: 2,
#          87.53999999999996: 2,
#          103.57000000000005: 2,
#          46.460000000000036: 2,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
# ...

# %%
google.drop(columns=['lagged', 'shifted'], inplace=True)
google
# Out:
#              Close
# Date
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-06  558.10
# 2014-01-07  568.86
# 2014-01-08  570.04
# ...            ...
# 2016-12-26     NaN
# 2016-12-27  791.55
# 2016-12-28  785.05
# 2016-12-29  782.79
# 2016-12-30  771.82
#
# [782 rows x 1 columns]

# %%
google['daily_returned'] = google.Close.pct_change(1, fill_method=None).mul(100)
google['monthly_returned'] = google.Close.pct_change(30, fill_method=None).mul(100)
google['annual_returned'] = google.Close.pct_change(360, fill_method=None).mul(100)

# %%
google.plot(subplots=True)
plt.show()

# %%
prices = pd.read_csv('asset_classes.csv', index_col=['DATE'], parse_dates=['DATE'])

# %%
prices.head()
# Out:
#               SP500   Bonds    Gold    Oil
# DATE
# 2007-06-29  1503.35  402.15  648.50  70.47
# 2007-07-02  1519.43  402.96  650.50  71.11
# 2007-07-03  1524.87  402.02  657.25  71.41
# 2007-07-05  1525.40  400.15  655.90  71.81
# 2007-07-06  1530.44  399.31  647.75  72.80

# %%
first_prices = prices.iloc[0]

# %%
normalized = prices.div(first_prices).mul(100)

# %%
normalized.plot()
plt.show()

# %%
stocks = pd.read_csv('nyse.csv', index_col=['date'], parse_dates=True)
down_jones = pd.read_csv('dow_jones.csv', index_col=['date'], parse_dates=True)

# %%
stocks.head()
# Out:
#               JNJ    JPM    XOM
# date
# 2010-01-04  64.68  42.85  69.15
# 2010-01-05  63.93  43.68  69.42
# 2010-01-06  64.45  43.92  70.02
# 2010-01-07  63.99  44.79  69.80
# 2010-01-08  64.21  44.68  69.52

# %%
down_jones.head()
# Out:
#                 DJIA
# date
# 2010-01-04  10583.96
# 2010-01-05  10572.02
# 2010-01-06  10573.68
# 2010-01-07  10606.86
# 2010-01-08  10618.19

# %%
data = pd.concat([stocks, down_jones], axis=1)

# %%
data
# Out:
#                JNJ    JPM    XOM      DJIA
# date
# 2010-01-04   64.68  42.85  69.15  10583.96
# 2010-01-05   63.93  43.68  69.42  10572.02
# 2010-01-06   64.45  43.92  70.02  10573.68
# 2010-01-07   63.99  44.79  69.80  10606.86
# 2010-01-08   64.21  44.68  69.52  10618.19
# ...            ...    ...    ...       ...
# 2016-12-23  115.96  87.05  90.71  19933.81
# 2016-12-27  115.91  87.13  90.75  19945.04
# 2016-12-28  115.10  86.50  90.30  19833.68
# 2016-12-29  115.49  85.89  90.35  19819.78
# 2016-12-30  115.21  86.29  90.26  19762.60
#
# [1762 rows x 4 columns]

# %%
data.div(data.iloc[0]).mul(100).plot()
plt.show()

# %%
start = '2025-01-01'
end = '2025-02-28'

# %%
monthly_dates = pd.date_range(start, end, freq='MS')
monthly_dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-02-01'], dtype='datetime64[ns]', freq='MS')

# %%
monthly = pd.Series([1, 2], index=monthly_dates )
monthly
# Out:
# 2025-01-01    1
# 2025-02-01    2
# Freq: MS, dtype: int64

# %%
weekly_dates = pd.date_range(start, end, freq='W')

# %%
monthly.reindex(weekly_dates)
# Out:
# 2025-01-05   NaN
# 2025-01-12   NaN
# 2025-01-19   NaN
# 2025-01-26   NaN
# 2025-02-02   NaN
# 2025-02-09   NaN
# 2025-02-16   NaN
# 2025-02-23   NaN
# Freq: W-SUN, dtype: float64

# %%
monthly.reindex(weekly_dates, method='bfill')
# Out:
# 2025-01-05    2.0
# 2025-01-12    2.0
# 2025-01-19    2.0
# 2025-01-26    2.0
# 2025-02-02    NaN
# 2025-02-09    NaN
# 2025-02-16    NaN
# 2025-02-23    NaN
# Freq: W-SUN, dtype: float64

# %%
monthly.reindex(weekly_dates, method='ffill')
# Out:
# 2025-01-05    1
# 2025-01-12    1
# 2025-01-19    1
# 2025-01-26    1
# 2025-02-02    2
# 2025-02-09    2
# 2025-02-16    2
# 2025-02-23    2
# Freq: W-SUN, dtype: int64

# %%
google.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2016-12-19', '2016-12-20', '2016-12-21', '2016-12-22',
#                '2016-12-23', '2016-12-26', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=782, freq='B')

# %%
yahoo.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07',
#                '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11',
#                '2013-01-14', '2013-01-15',
#                ...
#                '2015-12-18', '2015-12-21', '2015-12-22', '2015-12-23',
#                '2015-12-24', '2015-12-25', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name='date', length=782, freq=None)

# %%
monthly = pd.read_csv('unrate.csv', index_col=['DATE'], parse_dates=True)
monthly.head()
# Out:
#             UNRATE
# DATE
# 2010-01-01     9.8
# 2010-02-01     9.8
# 2010-03-01     9.9
# 2010-04-01     9.9
# 2010-05-01     9.6

# %%
weekly_dates = pd.date_range(start=monthly.index.min() , end=monthly.index.max(), freq='1D')

# %%
weekly = monthly.reindex(weekly_dates)

# %%
weekly
# Out:
#             UNRATE
# 2010-01-03     NaN
# 2010-01-10     NaN
# 2010-01-17     NaN
# 2010-01-24     NaN
# 2010-01-31     NaN
# ...            ...
# 2016-12-04     NaN
# 2016-12-11     NaN
# 2016-12-18     NaN
# 2016-12-25     NaN
# 2017-01-01     4.8
#
# [366 rows x 1 columns]

# %%
weekly['ffill'] = weekly['UNRATE'].ffill()
weekly['interpolated'] = weekly['UNRATE'].interpolate()

# %%
weekly.plot()
plt.show()

# %%
weekly_dates = pd.date_range(start=monthly.index.min() , end=monthly.index.max(), freq='W')

# %%
ax = weekly.plot()
ax.scatter(weekly.index, weekly["UNRATE"])
plt.show()

# %%
monthly.index.min()
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
monthly.index.max()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
weekly.index.min()
# Out:
# Timestamp('2010-01-03 00:00:00')

# %%
weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2010-01-03 to 2017-01-01
# Freq: W-SUN
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UNRATE        13 non-null     float64
#  1   ffill         336 non-null    float64
#  2   interpolated  336 non-null    float64
# dtypes: float64(3)
# memory usage: 11.4 KB

# %%
ozone = pd.read_csv('ozone_nyla.csv', index_col=['date'], parse_dates=True)
ozone
# Out:
#             Los Angeles  New York
# date
# 2000-01-01     0.008375  0.004032
# 2000-01-02          NaN  0.009486
# 2000-01-03          NaN  0.005580
# 2000-01-04     0.005500  0.008717
# 2000-01-05     0.005000  0.013754
# ...                 ...       ...
# 2017-03-27          NaN  0.005640
# 2017-03-28          NaN  0.013870
# 2017-03-29          NaN  0.034341
# 2017-03-30          NaN  0.026059
# 2017-03-31          NaN  0.035983
#
# [6291 rows x 2 columns]

# %%
ozone.info
# Out:
# <bound method DataFrame.info of             Los Angeles  New York
# date
# 2000-01-01     0.008375  0.004032
# 2000-01-02          NaN  0.009486
# 2000-01-03          NaN  0.005580
# 2000-01-04     0.005500  0.008717
# 2000-01-05     0.005000  0.013754
# ...                 ...       ...
# 2017-03-27          NaN  0.005640
# 2017-03-28          NaN  0.013870
# 2017-03-29          NaN  0.034341
# 2017-03-30          NaN  0.026059
# 2017-03-31          NaN  0.035983
#
# [6291 rows x 2 columns]>

# %%
ozone.resample('W').mean().plot()
plt.show()

# %%
ozone.resample('YE').mean().plot()
plt.show()

# %%
gdp_growth = pd.read_csv('gdp_growth.csv', index_col=['date'], parse_dates=True)
gdp_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 41 entries, 2007-01-01 to 2017-01-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gdp_growth  41 non-null     float64
# dtypes: float64(1)
# memory usage: 656.0 bytes

# %%
djia = pd.read_csv('djia.csv', index_col=['date'], parse_dates=True)
djia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2610 entries, 2007-06-29 to 2017-06-29
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   djia    2519 non-null   float64
# dtypes: float64(1)
# memory usage: 40.8 KB

# %%
djia.head()
# Out:
#                 djia
# date
# 2007-06-29  13408.62
# 2007-07-02  13535.43
# 2007-07-03  13577.30
# 2007-07-04       NaN
# 2007-07-05  13565.84

# %%
djia_quarterly = djia.resample('QS').first()
djia_quarterly
# Out:
#                 djia
# date
# 2007-04-01  13408.62
# 2007-07-01  13535.43
# 2007-10-01  14087.55
# 2008-01-01  13043.96
# 2008-04-01  12654.36
# 2008-07-01  11382.26
# 2008-10-01  10831.07
# 2009-01-01   9034.69
# 2009-04-01   7761.60
# 2009-07-01   8504.06
# 2009-10-01   9509.28
# 2010-01-01  10583.96
# 2010-04-01  10927.07
# 2010-07-01   9732.53
# 2010-10-01  10829.68
# 2011-01-01  11670.75
# 2011-04-01  12376.72
# 2011-07-01  12582.77
# 2011-10-01  10655.30
# 2012-01-01  12397.38
# 2012-04-01  13264.49
# 2012-07-01  12871.39
# 2012-10-01  13515.11
# 2013-01-01  13412.55
# 2013-04-01  14572.85
# 2013-07-01  14974.96
# 2013-10-01  15191.70
# 2014-01-01  16441.35
# 2014-04-01  16532.61
# 2014-07-01  16956.07
# 2014-10-01  16804.71
# 2015-01-01  17832.99
# 2015-04-01  17698.18
# 2015-07-01  17757.91
# 2015-10-01  16272.01
# 2016-01-01  17148.94
# 2016-04-01  17792.75
# 2016-07-01  17949.37
# 2016-10-01  18253.85
# 2017-01-01  19881.76
# 2017-04-01  20650.21

# %%
djia_quarterly_return = djia_quarterly.pct_change().mul(100)
djia_quarterly_return
# Out:
#                  djia
# date
# 2007-04-01        NaN
# 2007-07-01   0.945735
# 2007-10-01   4.079072
# 2008-01-01  -7.407889
# 2008-04-01  -2.986823
# 2008-07-01 -10.052662
# 2008-10-01  -4.842536
# 2009-01-01 -16.585434
# 2009-04-01 -14.091131
# 2009-07-01   9.565811
# 2009-10-01  11.820472
# 2010-01-01  11.301381
# 2010-04-01   3.241792
# 2010-07-01 -10.931933
# 2010-10-01  11.273019
# 2011-01-01   7.766342
# 2011-04-01   6.049054
# 2011-07-01   1.664819
# 2011-10-01 -15.318328
# 2012-01-01  16.349422
# 2012-04-01   6.994300
# 2012-07-01  -2.963552
# 2012-10-01   5.001169
# 2013-01-01  -0.758854
# 2013-04-01   8.650853
# 2013-07-01   2.759309
# 2013-10-01   1.447349
# 2014-01-01   8.225873
# 2014-04-01   0.555064
# 2014-07-01   2.561362
# 2014-10-01  -0.892660
# 2015-01-01   6.118999
# 2015-04-01  -0.755958
# 2015-07-01   0.337492
# 2015-10-01  -8.367539
# 2016-01-01   5.389193
# 2016-04-01   3.754226
# 2016-07-01   0.880246
# 2016-10-01   1.696327
# 2017-01-01   8.918173
# ...

# %%
gdp_growth
# Out:
#             gdp_growth
# date
# 2007-01-01         0.2
# 2007-04-01         3.1
# 2007-07-01         2.7
# 2007-10-01         1.4
# 2008-01-01        -2.7
# 2008-04-01         2.0
# 2008-07-01        -1.9
# 2008-10-01        -8.2
# 2009-01-01        -5.4
# 2009-04-01        -0.5
# 2009-07-01         1.3
# 2009-10-01         3.9
# 2010-01-01         1.7
# 2010-04-01         3.9
# 2010-07-01         2.7
# 2010-10-01         2.5
# 2011-01-01        -1.5
# 2011-04-01         2.9
# 2011-07-01         0.8
# 2011-10-01         4.6
# 2012-01-01         2.7
# 2012-04-01         1.9
# 2012-07-01         0.5
# 2012-10-01         0.1
# 2013-01-01         2.8
# 2013-04-01         0.8
# 2013-07-01         3.1
# 2013-10-01         4.0
# 2014-01-01        -1.2
# 2014-04-01         4.0
# 2014-07-01         5.0
# 2014-10-01         2.3
# 2015-01-01         2.0
# 2015-04-01         2.6
# 2015-07-01         2.0
# 2015-10-01         0.9
# 2016-01-01         0.8
# 2016-04-01         1.4
# ...

# %%
data = pd.concat([gdp_growth, djia_quarterly_return], axis=1)
data
# Out:
#             gdp_growth       djia
# date
# 2007-01-01         0.2        NaN
# 2007-04-01         3.1        NaN
# 2007-07-01         2.7   0.945735
# 2007-10-01         1.4   4.079072
# 2008-01-01        -2.7  -7.407889
# 2008-04-01         2.0  -2.986823
# 2008-07-01        -1.9 -10.052662
# 2008-10-01        -8.2  -4.842536
# 2009-01-01        -5.4 -16.585434
# 2009-04-01        -0.5 -14.091131
# 2009-07-01         1.3   9.565811
# 2009-10-01         3.9  11.820472
# 2010-01-01         1.7  11.301381
# 2010-04-01         3.9   3.241792
# 2010-07-01         2.7 -10.931933
# 2010-10-01         2.5  11.273019
# 2011-01-01        -1.5   7.766342
# 2011-04-01         2.9   6.049054
# 2011-07-01         0.8   1.664819
# 2011-10-01         4.6 -15.318328
# 2012-01-01         2.7  16.349422
# 2012-04-01         1.9   6.994300
# 2012-07-01         0.5  -2.963552
# 2012-10-01         0.1   5.001169
# 2013-01-01         2.8  -0.758854
# 2013-04-01         0.8   8.650853
# ...

# %%
data.rename(columns={'gdp_growth': 'gpd'}, inplace=True)

# %%
data.plot()
plt.show()

# %%
sp500 = pd.read_csv('sp500.csv', index_col=['date'], parse_dates=True)
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2395 entries, 2007-06-29 to 2016-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SP500   2395 non-null   float64
# dtypes: float64(1)
# memory usage: 37.4 KB

# %%
sp500.head()
# Out:
#               SP500
# date
# 2007-06-29  1503.35
# 2007-07-02  1519.43
# 2007-07-03  1524.87
# 2007-07-05  1525.40
# 2007-07-06  1530.44

# %%
daily_returns = sp500.squeeze().pct_change()

# %%
stats = daily_returns.resample('MS').agg(['mean', 'median', 'std', 'min', 'max'])

# %%
stats.plot()
plt.show()

# %%
ozone = pd.read_csv('ozone_nyc.csv', index_col=['date'], parse_dates=True)
ozone.head()
# Out:
#                Ozone
# date
# 2000-01-01  0.004032
# 2000-01-02  0.009486
# 2000-01-03  0.005580
# 2000-01-04  0.008717
# 2000-01-05  0.013754

# %%
ozone['90D'] = ozone['Ozone'].rolling(window='90D').mean()
ozone['360D'] = ozone['Ozone'].rolling(window='360D').mean()

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
ozone.head()
# Out:
#                Ozone       90D      360D
# date
# 2000-01-01  0.004032  0.004032  0.004032
# 2000-01-02  0.009486  0.006759  0.006759
# 2000-01-03  0.005580  0.006366  0.006366
# 2000-01-04  0.008717  0.006954  0.006954
# 2000-01-05  0.013754  0.008314  0.008314

# %%
ozone.loc[:'2001'].plot(title='New York City')
plt.show()

# %%
stats = ozone.Ozone.rolling(360, min_periods=1).agg(['mean', 'std'])
stats
# Out:
#                 mean       std
# date
# 2000-01-01  0.004032       NaN
# 2000-01-02  0.006759  0.003856
# 2000-01-03  0.006366  0.002811
# 2000-01-04  0.006954  0.002578
# 2000-01-05  0.008314  0.003773
# ...              ...       ...
# 2017-03-27  0.026629  0.011599
# 2017-03-28  0.026583  0.011617
# 2017-03-29  0.026584  0.011617
# 2017-03-30  0.026599  0.011613
# 2017-03-31  0.026607  0.011618
#
# [6291 rows x 2 columns]

# %%
stats = ozone.join(stats)
stats
# Out:
#                Ozone       90D      360D      mean       std
# date
# 2000-01-01  0.004032  0.004032  0.004032  0.004032       NaN
# 2000-01-02  0.009486  0.006759  0.006759  0.006759  0.003856
# 2000-01-03  0.005580  0.006366  0.006366  0.006366  0.002811
# 2000-01-04  0.008717  0.006954  0.006954  0.006954  0.002578
# 2000-01-05  0.013754  0.008314  0.008314  0.008314  0.003773
# ...              ...       ...       ...       ...       ...
# 2017-03-27  0.005640  0.021992  0.026629  0.026629  0.011599
# 2017-03-28  0.013870  0.021999  0.026583  0.026583  0.011617
# 2017-03-29  0.034341  0.022235  0.026584  0.026584  0.011617
# 2017-03-30  0.026059  0.022334  0.026599  0.026599  0.011613
# 2017-03-31  0.035983  0.022467  0.026607  0.026607  0.011618
#
# [6291 rows x 5 columns]

# %%
ozone.head()
# Out:
#                Ozone
# date
# 2000-01-01  0.004032
# 2000-01-02  0.009486
# 2000-01-03  0.005580
# 2000-01-04  0.008717
# 2000-01-05  0.013754

# %%
data = ozone.resample('D').interpolate()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6300 entries, 2000-01-01 to 2017-03-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ozone   6300 non-null   float64
# dtypes: float64(1)
# memory usage: 98.4 KB

# %%
rolling = data.rolling(360)

# %%
data['q10'] = rolling.quantile(0.1)
data['q50'] = rolling.quantile(0.5)
data['q90'] = rolling.quantile(0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6639/16151025.py in ?()
# ----> 1 data['q10'] = rolling.quantile(0.1)
#       2 data['q50'] = rolling.quantile(0.5)
#       3 data['q90'] = rolling.quantile(0.9)
#
# ~/projects/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~/projects/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, key, value)
# ...

# %%
google = pd.read_csv('google.csv', index_col=['Date'], parse_dates=True)

# %%
google.head()
# Out:
#              Close
# Date
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-04     NaN
# 2014-01-05     NaN
# 2014-01-06  558.10

# %%
differences =   google.diff().dropna()

# %%
differences
# Out:
#             Close
# Date
# 2014-01-03  -4.05
# 2014-01-07  10.76
# 2014-01-08   1.18
# 2014-01-09  -5.49
# 2014-01-10  -0.03
# ...           ...
# 2016-12-22  -3.30
# 2016-12-23  -1.35
# 2016-12-28  -6.50
# 2016-12-29  -2.26
# 2016-12-30 -10.97
#
# [594 rows x 1 columns]

# %%
start_price = pd.DataFrame(google.iloc[0, :]).T
start_price
# Out:
#             Close
# 2014-01-02  556.0

# %%
cumulative_sum = pd.concat([start_price, differences], axis=0).cumsum()
cumulative_sum
# Out:
#              Close
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-07  562.71
# 2014-01-08  563.89
# 2014-01-09  558.40
# ...            ...
# 2016-12-22  740.39
# 2016-12-23  739.04
# 2016-12-28  732.54
# 2016-12-29  730.28
# 2016-12-30  719.31
#
# [595 rows x 1 columns]

# %%
cumulative_sum.plot()
plt.show()

# %%
google.equals(cumulative_sum)
# Out:
# False

# %%
investment = 1000

# %%
stocks = pd.read_csv('apple_google.csv', index_col=['Date'], parse_dates=True)
stocks.head()
# Out:
#             AAPL    GOOG
# Date
# 2010-01-04   NaN  313.06
# 2010-01-05   NaN  311.68
# 2010-01-06   NaN  303.83
# 2010-01-07   NaN  296.75
# 2010-01-08   NaN  300.71

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1864 entries, 2010-01-04 to 2017-05-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    1624 non-null   float64
#  1   GOOG    1864 non-null   float64
# dtypes: float64(2)
# memory usage: 43.7 KB

# %%
stocks.dtypes
# Out:
# AAPL    float64
# GOOG    float64
# dtype: object

# %%
returns = stocks.pct_change()

# %%
returns
# Out:
#                 AAPL      GOOG
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05       NaN -0.004408
# 2010-01-06       NaN -0.025186
# 2010-01-07       NaN -0.023303
# 2010-01-08       NaN  0.013345
# ...              ...       ...
# 2017-05-24 -0.002991  0.006471
# 2017-05-25  0.003456  0.015268
# 2017-05-26 -0.001690  0.001991
# 2017-05-30  0.000391  0.004540
# 2017-05-31 -0.005922 -0.011292
#
# [1864 rows x 2 columns]

# %%
returns = returns + 1

# %%
cumulative_return = returns.cumprod()
cumulative_return
# Out:
#                 AAPL      GOOG
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05       NaN  0.995592
# 2010-01-06       NaN  0.970517
# 2010-01-07       NaN  0.947901
# 2010-01-08       NaN  0.960551
# ...              ...       ...
# 2017-05-24  3.341469  3.050406
# 2017-05-25  3.353018  3.096978
# 2017-05-26  3.347352  3.103143
# 2017-05-30  3.348660  3.117230
# 2017-05-31  3.328830  3.082029
#
# [1864 rows x 2 columns]

# %%
cumulative_return.mul(investment).plot()
plt.show()

# %%
import numpy as np

# %%
np.random.seed(42)

# %%
random_walk = np.random.normal(loc=.001, scale=.01, size=2500)

# %%
random_walk
# Out:
# array([ 0.00596714, -0.00038264,  0.00747689, ..., -0.0017976 ,
#         0.00890372,  0.00440051], shape=(2500,))

# %%
random_walk = pd.Series(random_walk)

# %%
random_prices = random_walk.add(1).cumprod()

# %%
random_prices.mul(1000).plot()
plt.show()

# %%
fb = pd.read_csv('fb.csv', index_col=0, parse_dates=True, header=None, names=['Date', 'stock_price'])
fb
# Out:
#             stock_price
# Date
# 2012-05-17        38.00
# 2012-05-18        38.23
# 2012-05-21        34.03
# 2012-05-22        31.00
# 2012-05-23        32.00
# ...                 ...
# 2017-05-24       150.04
# 2017-05-25       151.96
# 2017-05-26       152.13
# 2017-05-30       152.38
# 2017-05-31       151.46
#
# [1267 rows x 1 columns]

# %%
daily_returns = fb.pct_change().dropna()

# %%
n_observation = daily_returns.shape[0]
n_observation
# Out:
# 1266

# %%
random_walk = np.random.choice(daily_returns.squeeze(), n_observation)

# %%
random_walk = pd.Series(random_walk)

# %%
import seaborn as sns

# %%
sns.displot(random_walk, kde=True)
plt.show()
